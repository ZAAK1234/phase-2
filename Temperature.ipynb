# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
for i in df.columns:
  print('**'*25)
  print(df[i].value_counts())
# Out:
# **************************************************
# station
# 1.0     310
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 13.0    310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: count, dtype: int64
# **************************************************
# Date
# 30-06-2013    25
# 18-07-2016    25
# 25-07-2016    25
# 24-07-2016    25
# 23-07-2016    25
#               ..
# 09-08-2014    25
# 08-08-2014    25
# 07-08-2014    25
# 06-08-2014    25
# 30-08-2017    25
# Name: count, Length: 310, dtype: int64
# **************************************************
# Present_Tmax
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy='mean')

# %%
cat_col=[]
num_col=[]
for i in df.columns:
  if df[i].dtypes == 'int' or df[i].dtypes == 'float':
    num_col.append(i)
  if df[i].dtype == 'O':
    cat_col.append(i)

# %%
for i in num_col:
  df[i]=imp.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750     13.0         NaN          20.0          11.3    19.794666
# 7751     13.0         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.dropna(subset=['Date'], inplace=True)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Date']=le.fit_transform(df['Date'])

# %%
df
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    58.255688    91.116364
# 1         2.0   290          31.9          21.6    52.263397    90.604721
# 2         3.0   290          31.6          23.3    48.690479    83.973587
# 3         4.0   290          32.0          23.4    58.239788    96.483688
# 4         5.0   290          31.4          21.9    56.174095    90.155128
# ...       ...   ...           ...           ...          ...          ...
# 7745     21.0   304          23.1          17.8    24.688997    78.261383
# 7746     22.0   304          22.5          17.4    30.094858    83.690018
# 7747     23.0   304          23.3          17.1    26.741310    78.869858
# 7748     24.0   304          23.3          17.7    24.040634    77.294975
# 7749     25.0   304          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  \
# ...

# %%
df['Date'].value_counts()
# Out:
# Date
# 290    25
# 173    25
# 243    25
# 233    25
# 223    25
#        ..
# 86     25
# 76     25
# 66     25
# 56     25
# 304    25
# Name: count, Length: 310, dtype: int64

# %%
df.skew()
# Out:
# station             0.000000
# Date                0.000000
# Present_Tmax       -0.263013
# Present_Tmin       -0.357565
# LDAPS_RHmin         0.300229
# LDAPS_RHmax        -0.850657
# LDAPS_Tmax_lapse   -0.224207
# LDAPS_Tmin_lapse   -0.579033
# LDAPS_WS            1.556422
# LDAPS_LH            0.667582
# LDAPS_CC1           0.459193
# LDAPS_CC2           0.471965
# LDAPS_CC3           0.640088
# LDAPS_CC4           0.665829
# LDAPS_PPT1          5.324404
# LDAPS_PPT2          5.713247
# LDAPS_PPT3          6.368693
# LDAPS_PPT4          6.743231
# lat                 0.086942
# lon                -0.285300
# DEM                 1.723944
# Slope               1.563346
# Solar radiation    -0.511006
# Next_Tmax          -0.335956
# Next_Tmin          -0.396873
# dtype: float64

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in df.columns.tolist():
  sns.distplot(df[i])
  plt.show()

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from scipy.stats import skew
skewnes_val=df.skew()
skewed_col=skewnes_val[abs(skewnes_val)>0.8].index.tolist()
skewed_col
# Out:
# ['LDAPS_RHmax',
#  'LDAPS_WS',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'DEM',
#  'Slope']

# %%
for i in skewed_col:
  df[i]=np.log1p(df[i])

# %%
df.skew()
# Out:
# station             0.000000
# Date                0.000000
# Present_Tmax       -0.263013
# Present_Tmin       -0.357565
# LDAPS_RHmin         0.300229
# LDAPS_RHmax        -1.071420
# LDAPS_Tmax_lapse   -0.224207
# LDAPS_Tmin_lapse   -0.579033
# LDAPS_WS            0.679982
# LDAPS_LH            0.667582
# LDAPS_CC1           0.459193
# LDAPS_CC2           0.471965
# LDAPS_CC3           0.640088
# LDAPS_CC4           0.665829
# LDAPS_PPT1          2.737265
# LDAPS_PPT2          3.167716
# LDAPS_PPT3          3.989556
# LDAPS_PPT4          4.205360
# lat                 0.086942
# lon                -0.285300
# DEM                 0.443948
# Slope               0.836180
# Solar radiation    -0.511006
# Next_Tmax          -0.335956
# Next_Tmin          -0.396873
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7750 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   int64
#  2   Present_Tmax      7750 non-null   float64
#  3   Present_Tmin      7750 non-null   float64
#  4   LDAPS_RHmin       7750 non-null   float64
#  5   LDAPS_RHmax       7750 non-null   float64
#  6   LDAPS_Tmax_lapse  7750 non-null   float64
#  7   LDAPS_Tmin_lapse  7750 non-null   float64
#  8   LDAPS_WS          7750 non-null   float64
#  9   LDAPS_LH          7750 non-null   float64
#  10  LDAPS_CC1         7750 non-null   float64
#  11  LDAPS_CC2         7750 non-null   float64
#  12  LDAPS_CC3         7750 non-null   float64
#  13  LDAPS_CC4         7750 non-null   float64
#  14  LDAPS_PPT1        7750 non-null   float64
#  15  LDAPS_PPT2        7750 non-null   float64
# ...

# %%
df['Next_Tmin'].std()
# Out:
# 2.478851379587978

# %% [markdown]
# # **For Min Temp.**

# %%
X=df.drop(columns='Next_Tmin')
X
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    58.255688     4.523053
# 1         2.0   290          31.9          21.6    52.263397     4.517483
# 2         3.0   290          31.6          23.3    48.690479     4.442340
# 3         4.0   290          32.0          23.4    58.239788     4.579685
# 4         5.0   290          31.4          21.9    56.174095     4.512563
# ...       ...   ...           ...           ...          ...          ...
# 7745     21.0   304          23.1          17.8    24.688997     4.372751
# 7746     22.0   304          22.5          17.4    30.094858     4.438998
# 7747     23.0   304          23.3          17.1    26.741310     4.380399
# 7748     24.0   304          23.3          17.7    24.040634     4.360483
# 7749     25.0   304          23.2          17.4    22.933014     4.359829
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  \
# ...

# %%
y=df['Next_Tmin']
y
# Out:
# 0       21.2
# 1       22.5
# 2       23.9
# 3       24.3
# 4       22.5
#         ...
# 7745    17.7
# 7746    17.1
# 7747    18.1
# 7748    18.8
# 7749    17.4
# Name: Next_Tmin, Length: 7750, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model={'Linear Regression':LinearRegression(),'Ridge':Ridge(alpha=0.1),'Lasso':Lasso(alpha=0.1),'ElasticNet':ElasticNet(alpha=0.1),'DecisionTreeRegression':DecisionTreeRegressor(),'SVR':SVR(),'RandomForestRegressor':RandomForestRegressor(),'GradientBoostingRegresssor':GradientBoostingRegressor()}
for i,j in model.items():
  j.fit(X_train,y_train)
  pred=j.predict(X_test)
  mse=mean_squared_error(y_test,pred)
  r2=r2_score(y_test,pred)
  print(f'Model : {i}')
  print(f'MSE is {mse:.3f}')
  print(f'R2-Score is {r2:.3f}')
  print(f'Score {j.score(X_test,y_test)}')
  print('\n')
best_model=max(model.values(), key=lambda j: j.score(X_test,y_test))
print(f'Best Model is {best_model} and score is {best_model.score(X_test,y_test)}')
# Out:
# Model : Linear Regression
# MSE is 0.880
# R2-Score is 0.849
# Score 0.8494970302877485
#
#
# Model : Ridge
# MSE is 0.880
# R2-Score is 0.850
# Score 0.8495034392630947
#
#
# Model : Lasso
# MSE is 0.964
# R2-Score is 0.835
# Score 0.8351638509503152
#
#
# Model : ElasticNet
# MSE is 0.949
# R2-Score is 0.838
# Score 0.8377365170692125
#
#
# Model : DecisionTreeRegression
# MSE is 1.240
# R2-Score is 0.788
# Score 0.7880156349742136
#
#
# Model : SVR
# MSE is 5.228
# R2-Score is 0.106
# Score 0.10595826383727125
#
#
# Model : RandomForestRegressor
# MSE is 0.551
# R2-Score is 0.906
# Score 0.9057908201603173
#
#
# Model : GradientBoostingRegresssor
# MSE is 0.616
# R2-Score is 0.895
# Score 0.8946080624195885
#
#
# Best Model is RandomForestRegressor() and score is 0.9057908201603173

# %% [markdown]
# # **For Max Temp.**

# %%
X=df.drop(columns='Next_Tmax',axis=1)
X
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    58.255688     4.523053
# 1         2.0   290          31.9          21.6    52.263397     4.517483
# 2         3.0   290          31.6          23.3    48.690479     4.442340
# 3         4.0   290          32.0          23.4    58.239788     4.579685
# 4         5.0   290          31.4          21.9    56.174095     4.512563
# ...       ...   ...           ...           ...          ...          ...
# 7745     21.0   304          23.1          17.8    24.688997     4.372751
# 7746     22.0   304          22.5          17.4    30.094858     4.438998
# 7747     23.0   304          23.3          17.1    26.741310     4.380399
# 7748     24.0   304          23.3          17.7    24.040634     4.360483
# 7749     25.0   304          23.2          17.4    22.933014     4.359829
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  \
# ...

# %%
y=df['Next_Tmax']
y
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7745    27.6
# 7746    28.0
# 7747    28.3
# 7748    28.6
# 7749    27.8
# Name: Next_Tmax, Length: 7750, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
for i,j in model.items():
  j.fit(X_train,y_train)
  pred=j.predict(X_test)
  mse=mean_squared_error(y_test,pred)
  r2=r2_score(y_test,pred)
  print(f'Model : {i}')
  print(f'MSE Value is {mse:.5f}')
  print(f'R-Score is {r2:.5f}')
  print(f'Model Score is {j.score(X_test,y_test)}')
  print('\n')
best_model=max(model.values(),key= lambda j: j.score(X_test,y_test))
print(f'Best Model is {best_model} with score {best_model.score(X_test,y_test)}')
# Out:
# Model : Linear Regression
# MSE Value is 1.99880
# R-Score is 0.78966
# Model Score is 0.7896615222967056
#
#
# Model : Ridge
# MSE Value is 1.99883
# R-Score is 0.78966
# Model Score is 0.7896586747009345
#
#
# Model : Lasso
# MSE Value is 2.49347
# R-Score is 0.73761
# Model Score is 0.7376060865668509
#
#
# Model : ElasticNet
# MSE Value is 2.37424
# R-Score is 0.75015
# Model Score is 0.750153646636317
#
#
# Model : DecisionTreeRegression
# MSE Value is 2.01684
# R-Score is 0.78776
# Model Score is 0.7877636458682735
#
#
# Model : SVR
# MSE Value is 9.04008
# R-Score is 0.04869
# Model Score is 0.048691647885775735
#
#
# Model : RandomForestRegressor
# MSE Value is 0.89156
# R-Score is 0.90618
# Model Score is 0.9061792649012099
#
#
# Model : GradientBoostingRegresssor
# MSE Value is 1.29971
# R-Score is 0.86323
# Model Score is 0.8632279820590926
#
#
# Best Model is RandomForestRegressor() with score 0.9061792649012099

# %%
best_model=
